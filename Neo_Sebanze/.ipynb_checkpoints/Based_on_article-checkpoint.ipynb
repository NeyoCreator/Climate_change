# %%
#from comet_ml import Experiment

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

##Data Cleaning
import nltk #
import string #to remove all punctuation marks in the corpus/ document
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
from nltk import SnowballStemmer, PorterStemmer, LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from sklearn.model_selection import train_test_split

ps = nltk.PorterStemmer()

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report, accuracy_score
# set plot style
sns.set()

# %% [markdown]
# # __Loading data__

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv('test.csv')

# %% [markdown]
# Show the full detail whithin a dataframe

# %%
pd.set_option("display.max_colwidth", -1)
# Out:
# <ipython-input-3-a09e5efec013>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option("display.max_colwidth", -1)

# %%
#view original dataframe 
df_train.head()
# Out:
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid
# 0  625221
# 1  126103
# 2  698562
# 3  573736
# 4  466954

# %% [markdown]
# # __import comet__

# %%
# Create an experiment with your api key

# %% [markdown]
# # 1.__Removing twitter handles__

# %% [markdown]
# We remove the twitter handles from the dataset because it doesn't contribute to `solving our problem`

# %%
# function to remove the pattern ‘@user’ from all the tweets in our data.
def remove_pattern(text,pattern):
    
    # re.findall() finds the pattern i.e @user and puts it in a list for further task
    r = re.findall(pattern,text)
    
    # re.sub() removes @user from the sentences in the dataset
    for i in r:
        text = re.sub(i,"",text)
    
    return text

# %%
df_train['removed_user'] = np.vectorize(remove_pattern)(df_train['message'], "@[\w]*")
df_train.head()
# Out:
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid  \
# 0  625221
# 1  126103
# 2  698562
# 3  573736
# 4  466954
#
#                                                                                                                           removed_user
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT : Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT : It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight

# %% [markdown]
# #  2.__Removing short words__

# %% [markdown]
# Removing words that have a length less than `3`.

# %%
df_train['short_words'] = df_train['removed_user'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

df_train.head(10)
# Out:
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
# 5  1
# 6  1
# 7  1
# 8  1
# 9  1
#
#                                                                                                                                                     message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
# 5  Worth a read whether you do or don't believe in climate change https://t.co/ggLZVNYjun https://t.co/7AFE2mAH8j
# 6  RT @thenation: Mike Pence doesn’t believe in global warming or that smoking causes lung cancer. https://t.co/gvWYaauU8R
# 7  RT @makeandmendlife: Six big things we can ALL do today to fight climate change, or how to be a climate activistÃ¢â‚¬Â¦ https://t.co/TYMLu6DbNM hÃ¢â‚¬Â¦
# 8  @AceofSpadesHQ My 8yo nephew is inconsolable. He wants to die of old age like me, but will perish in the fiery hellscape of climate change.
# 9  RT @paigetweedy: no offense… but like… how do you just not believe… in global warming………
#
#    tweetid  \
# 0  625221
# 1  126103
# 2  698562
# 3  573736
# 4  466954
# 5  425577
# 6  294933
# 7  992717
# 8  664510
# 9  260471
#
#                                                                                                                                removed_user  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT : Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT : It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
# 5  Worth a read whether you do or don't believe in climate change https://t.co/ggLZVNYjun https://t.co/7AFE2mAH8j
# 6  RT : Mike Pence doesn’t believe in global warming or that smoking causes lung cancer. https://t.co/gvWYaauU8R
# 7  RT : Six big things we can ALL do today to fight climate change, or how to be a climate activistÃ¢â‚¬Â¦ https://t.co/TYMLu6DbNM hÃ¢â‚¬Â¦
# 8   My 8yo nephew is inconsolable. He wants to die of old age like me, but will perish in the fiery hellscape of climate change.
# 9  RT : no offense… but like… how do you just not believe… in global warming………
#
#                                                                                                             short_words
# 0  PolySciMajor chief doesn't think carbon dioxide main cause global warming and.. wait, what!? https://t.co/yeLvcEFXkC
# 1  It's like lack evidence anthropogenic global warming
# 2  Researchers have three years climate change before it’s late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED 2016 pivotal year climate change https://t.co/44wOTxTLcD
# 4  It's 2016, racist, sexist, climate change denying bigot leading polls. #ElectionNight
# 5  Worth read whether don't believe climate change https://t.co/ggLZVNYjun https://t.co/7AFE2mAH8j
# 6  Mike Pence doesn’t believe global warming that smoking causes lung cancer. https://t.co/gvWYaauU8R
# 7  things today fight climate change, climate activistÃ¢â‚¬Â¦ https://t.co/TYMLu6DbNM hÃ¢â‚¬Â¦
# 8  nephew inconsolable. wants like will perish fiery hellscape climate change.
# 9  offense… like… just believe… global warming………

# %% [markdown]
#  # 3.__Remove url__

# %% [markdown]
# Remove urls and replace with `urlweb`

# %%
### Remove urls and replace them with the word 'url-web'
pattern_url = r'http[s]?://(?:[A-Za-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9A-Fa-f][0-9A-Fa-f]))+'
subs_url = r'urlweb'
df_train['removed_url'] = df_train['short_words'].replace(to_replace = pattern_url, value = subs_url, regex = True)

##Convert all lowercase to uppercase
df_train['removed_url'] = df_train['removed_url'].str.lower()


df_train.head()
# Out:
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid  \
# 0  625221
# 1  126103
# 2  698562
# 3  573736
# 4  466954
#
#                                                                                                                           removed_user  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT : Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT : It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#                                                                                                             short_words  \
# 0  PolySciMajor chief doesn't think carbon dioxide main cause global warming and.. wait, what!? https://t.co/yeLvcEFXkC
# 1  It's like lack evidence anthropogenic global warming
# 2  Researchers have three years climate change before it’s late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED 2016 pivotal year climate change https://t.co/44wOTxTLcD
# 4  It's 2016, racist, sexist, climate change denying bigot leading polls. #ElectionNight
#
#                                                                                            removed_url
# 0  polyscimajor chief doesn't think carbon dioxide main cause global warming and.. wait, what!? urlweb
# 1  it's like lack evidence anthropogenic global warming
# 2  researchers have three years climate change before it’s late urlweb urlweb…
# 3  #todayinmaker# wired 2016 pivotal year climate change urlweb
# 4  it's 2016, racist, sexist, climate change denying bigot leading polls. #electionnight

# %% [markdown]
# # 4.__Final Removal__

# %% [markdown]
# - punctuation
# - numbers
# - special character
#
# Here we will replace everything except `hashtags`

# %%
df_train['tidy_message'] = df_train['removed_url'].str.replace("[^a-zA-Z#]", " ")
# Out:
# <ipython-input-10-2a7c5de9261a>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_train['tidy_message'] = df_train['removed_url'].str.replace("[^a-zA-Z#]", " ")

# %%
df_train.head()
# Out:
#    sentiment  \
# 0  1
# 1  1
# 2  2
# 3  1
# 4  1
#
#                                                                                                                                         message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via @mashable
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#    tweetid  \
# 0  625221
# 1  126103
# 2  698562
# 3  573736
# 4  466954
#
#                                                                                                                           removed_user  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, what!? https://t.co/yeLvcEFXkC via
# 1  It's not like we lack evidence of anthropogenic global warming
# 2  RT : Researchers say we have three years to act on climate change before it’s too late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT : It's 2016, and a racist, sexist, climate change denying bigot is leading in the polls. #ElectionNight
#
#                                                                                                             short_words  \
# 0  PolySciMajor chief doesn't think carbon dioxide main cause global warming and.. wait, what!? https://t.co/yeLvcEFXkC
# 1  It's like lack evidence anthropogenic global warming
# 2  Researchers have three years climate change before it’s late https://t.co/WdT0KdUr2f https://t.co/Z0ANPT…
# 3  #TodayinMaker# WIRED 2016 pivotal year climate change https://t.co/44wOTxTLcD
# 4  It's 2016, racist, sexist, climate change denying bigot leading polls. #ElectionNight
#
#                                                                                            removed_url  \
# 0  polyscimajor chief doesn't think carbon dioxide main cause global warming and.. wait, what!? urlweb
# 1  it's like lack evidence anthropogenic global warming
# 2  researchers have three years climate change before it’s late urlweb urlweb…
# 3  #todayinmaker# wired 2016 pivotal year climate change urlweb
# 4  it's 2016, racist, sexist, climate change denying bigot leading polls. #electionnight
#
#                                                                                           tidy_message
# 0  polyscimajor chief doesn t think carbon dioxide main cause global warming and   wait  what   urlweb
# 1  it s like lack evidence anthropogenic global warming
# 2  researchers have three years climate change before it s late urlweb urlweb
# 3  #todayinmaker# wired      pivotal year climate change urlweb
# 4  it s       racist  sexist  climate change denying bigot leading polls  #electionnight

# %% [markdown]
# # 5.__Tokenization__

# %%
tokenized_tweet = df_train['tidy_message'].apply(lambda x: x.split())

tokenized_tweet.head()
# Out:
# 0    [polyscimajor, chief, doesn, t, think, carbon, dioxide, main, cause, global, warming, and, wait, what, urlweb]
# 1    [it, s, like, lack, evidence, anthropogenic, global, warming]
# 2    [researchers, have, three, years, climate, change, before, it, s, late, urlweb, urlweb]
# 3    [#todayinmaker#, wired, pivotal, year, climate, change, urlweb]
# 4    [it, s, racist, sexist, climate, change, denying, bigot, leading, polls, #electionnight]
# Name: tidy_message, dtype: object

# %% [markdown]
# # 6.__Stop words__

# %%
stopword = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(text):
    text=[word for word in text if word not in stopword]
    return text
stop_words = tokenized_tweet.apply(lambda x: remove_stopwords(x))
stop_words.head()
# Out:
# 0    [polyscimajor, chief, think, carbon, dioxide, main, cause, global, warming, wait, urlweb]
# 1    [like, lack, evidence, anthropogenic, global, warming]
# 2    [researchers, three, years, climate, change, late, urlweb, urlweb]
# 3    [#todayinmaker#, wired, pivotal, year, climate, change, urlweb]
# 4    [racist, sexist, climate, change, denying, bigot, leading, polls, #electionnight]
# Name: tidy_message, dtype: object

# %% [markdown]
# # 7.__Lemmatisation__

# %%
#nltk.download('wordnet')
def train_lemma(words, lemmatizer):
    return [lemmatizer.lemmatize(word) for word in words]  

lemmatizer = WordNetLemmatizer()

df_lemma = stop_words.apply(train_lemma, args=(lemmatizer, ))

# %% [markdown]
# # 8.__Final data__

# %%
df_lemma.head()
# Out:
# 0    [polyscimajor, chief, think, carbon, dioxide, main, cause, global, warming, wait, urlweb]
# 1    [like, lack, evidence, anthropogenic, global, warming]
# 2    [researcher, three, year, climate, change, late, urlweb, urlweb]
# 3    [#todayinmaker#, wired, pivotal, year, climate, change, urlweb]
# 4    [racist, sexist, climate, change, denying, bigot, leading, poll, #electionnight]
# Name: tidy_message, dtype: object

# %% [markdown]
# # 9.__Data visualization__

# %%
from wordcloud import WordCloud,ImageColorGenerator
from PIL import Image
import urllib
import requests

# %% [markdown]
# ### 9.1 __Generating wordcloud for tweets that are__ `anti-climate change`

# %%
anti_climate = ' '.join(text for text in df_train['tidy_message'][df_train['sentiment']==-1])

# %%
# combining the image with the dataset
Mask = np.array(Image.open(requests.get('http://clipart-library.com/image_gallery2/Twitter-PNG-Image.png', stream=True).raw))

# We use the ImageColorGenerator library from Wordcloud 
# Here we take the color of the image and impose it over our wordcloud
image_colors = ImageColorGenerator(Mask)

# Now we use the WordCloud function from the wordcloud library 
wc = WordCloud(background_color='black', height=1500, width=4000,mask=Mask).generate(anti_climate)

# %% [markdown]
# #### __Plot the word cloud__

# %%
# Size of the image generated 
plt.figure(figsize=(10,20))

# Here we recolor the words from the dataset to the image's color
# recolor just recolors the default colors to the image's blue color
# interpolation is used to smooth the image generated 
plt.imshow(wc.recolor(color_func=image_colors),interpolation="hamming")

plt.axis('off')
plt.show()

# %% [markdown]
# ### 9.2 __Generating wordcloud for tweets that are__ `pro change`

# %%
pro_climate_change = ' '.join(text for text in df_train['tidy_message'][df_train['sentiment']==2])

# %%
# combining the image with the dataset
Mask = np.array(Image.open(requests.get('http://clipart-library.com/image_gallery2/Twitter-PNG-Image.png', stream=True).raw))

# We use the ImageColorGenerator library from Wordcloud 
# Here we take the color of the image and impose it over our wordcloud
image_colors = ImageColorGenerator(Mask)

# Now we use the WordCloud function from the wordcloud library 
wc = WordCloud(background_color='black', height=1500, width=4000,mask=Mask).generate(pro_climate_change)

# %% [markdown]
# #### __Plot the word cloud__

# %%
# Size of the image generated 
plt.figure(figsize=(10,20))

# Here we recolor the words from the dataset to the image's color
# recolor just recolors the default colors to the image's blue color
# interpolation is used to smooth the image generated 
plt.imshow(wc.recolor(color_func=image_colors),interpolation="hamming")

plt.axis('off')
plt.show()

# %% [markdown]
# ### 9.2 __Extracting the hashtags from the tweets__

# %% [markdown]
# #Hashtaging a tweet can make it reach a wider audiance in that regard it would make a good keyword for our `model`. And give us a better consensus within our data

# %%
def Hashtags_Extract(x):
    hashtags=[]
    
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r'#(\w+)',i)
        hashtags.append(ht)
    
    return hashtags

# %% [markdown]
# #### __Pro climate change__

# %%
pro_climate_change = Hashtags_Extract(df_train['tidy_message'][df_train['sentiment']==2])

# %%
pro_climate_change
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['skpol'],
#  [],
#  ['parisagreement'],
#  ['climate', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'india'],
#  ['greatbarrierreef', 'greatbarrierreef'],
#  [],
#  [],
#  ['exxonmobil'],
#  ['greatbarrierreef'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange', 'cop'],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  ['geographyteacher', 'climatechange'],
#  [],
#  ['mgwvjaiye'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cleanenergy'],
#  ['today'],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  ['ceta', 'cetat'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['wine', 'europe'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['worldpenguinday'],
#  [],
#  [],
#  [],
#  ['lastnightinsweden'],
#  ['environment'],
#  ['nbc'],
#  [],
#  [],
#  [],
#  ['news', 'bibleprophecy', 'truth', 'knowledge'],
#  ['cop'],
#  [],
#  [],
#  ['smartnews'],
#  [],
#  ['climatechange'],
#  ['shellknew'],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cdnpoli'],
#  [],
#  ['cyclonedebbie', 'climate'],
#  ['feedly'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['parisagreement'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'glo'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  ['climate'],
#  [],
#  ['inauguration'],
#  ['paginanuova'],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  ['demforce'],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  ['dsnworld'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['globalwarning'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['bigdata'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ankara', 'london', 'berlin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['news'],
#  [],
#  [],
#  [],
#  [],
#  ['nzpol'],
#  [],
#  [],
#  [],
#  ['data', 'environment', 'climatechange'],
#  [],
#  [],
#  ['unfao', 'readon'],
#  [],
#  [],
#  [],
#  [],
#  ['dsnscience', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['maga', 'america'],
#  ['climate'],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['politics'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['tech'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trump'],
#  ['climate', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['snowycats'],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'gpc'],
#  [],
#  ['longisland', 'technews'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'norway'],
#  [],
#  ['cop'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['drainthesw'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['newsintweets'],
#  ['worldwetlandsday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['egypt', 'france', 'italy'],
#  [],
#  [],
#  ['climate', 'globalwarming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['news', 'follow', 'retweet'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['wine'],
#  [],
#  [],
#  [],
#  ['climate'],
#  ['cleantech', 'environment', 'green'],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['indigenous'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  ['forest', 'climate', 'env'],
#  ['cop'],
#  [],
#  [],
#  ['ctl'],
#  [],
#  [],
#  [],
#  ['indigenous', 'rights', 'forests', 'climate', 'environment', 'biodiversity'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['germany', 'california', 'climatec'],
#  ['news', 'biotech'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['factoftheday'],
#  [],
#  [],
#  [],
#  [],
#  ['globalwarming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['russian'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hng', 'news', 'political'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'environment'],
#  [],
#  [],
#  ['cdnpoli'],
#  [],
#  [],
#  ['cnn'],
#  [],
#  [],
#  [],
#  ['dailyclimate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sab'],
#  ['worldnews'],
#  [],
#  [],
#  ['climatechange', 'globalwarming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  ['greatbarrierreef'],
#  [],
#  ['climate', 'trumppresident'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['unsg', 'cop'],
#  [],
#  [],
#  [],
#  [],
#  ['sapnajha'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'weather'],
#  ['maga', 'america'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cnn'],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  ['climate', 'environment'],
#  [],
#  [],
#  [],
#  [],
#  ['wsj'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['weather', 'forecast'],
#  ['forests'],
#  ['trump', 'climate', 'environment'],
#  ['science'],
#  [],
#  ['globalwarming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange', 'cop'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['earthday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['chemistrynewslocker'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['arnoldschwarzenegger', 'arnoldschwarzenegger'],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'ocean', 'environment'],
#  ['worldnews', 'news'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['science'],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  ['polarvortex'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['parisagreement'],
#  [],
#  ['weather', 'forecast'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['standingrock'],
#  [],
#  ['merc'],
#  [],
#  [],
#  [],
#  [],
#  ['cnn'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'globalwarming', 'beachlife'],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange', 'pollution', 'epa', 'uga'],
#  [],
#  ['epa', 'scottpruitt'],
#  [],
#  [],
#  [],
#  ['itstimetochange', 'cli'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate', 'environment'],
#  [],
#  ['breakingnews'],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  ['scitech'],
#  [],
#  [],
#  [],
#  ['cop'],
#  ['climatechange', 'globalwarming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['education'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['healthinformation'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['gameofthrones'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['environment', 'climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange', 'security', 'drought'],
#  [],
#  [],
#  ['worldnews', 'news'],
#  [],
#  ['climatechange'],
#  ['epa', 'climate', 'pruitt'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['arnoldschwarzenegger', 'arnoldschwarzenegger'],
#  [],
#  ['climatechange'],
#  ['cnnbrk'],
#  ['auspol'],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hng'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
pro_climate_change_unnest = sum(pro_climate_change, [])

# %%
pro_climate_change_unnest
# Out:
# ['climate',
#  'climatechange',
#  'climatechange',
#  'climate',
#  'skpol',
#  'parisagreement',
#  'climate',
#  'environment',
#  'climate',
#  'india',
#  'greatbarrierreef',
#  'greatbarrierreef',
#  'exxonmobil',
#  'greatbarrierreef',
#  'climatechange',
#  'cop',
#  'climatechange',
#  'geographyteacher',
#  'climatechange',
#  'mgwvjaiye',
#  'cleanenergy',
#  'today',
#  'climatechange',
#  'ceta',
#  'cetat',
#  'wine',
#  'europe',
#  'worldpenguinday',
#  'lastnightinsweden',
#  'environment',
#  'nbc',
#  'news',
#  'bibleprophecy',
#  'truth',
#  'knowledge',
#  'cop',
#  'smartnews',
#  'climatechange',
#  'shellknew',
#  'climatechange',
#  'cdnpoli',
#  'cyclonedebbie',
#  'climate',
#  'feedly',
#  'parisagreement',
#  'climate',
#  'glo',
#  'climatechange',
#  'climatechange',
#  'climate',
#  'inauguration',
#  'paginanuova',
#  'climate',
#  'demforce',
#  'climatechange',
#  'dsnworld',
#  'globalwarning',
#  'bigdata',
#  'climatechange',
#  'climatechange',
#  'ankara',
#  'london',
#  'berlin',
#  'news',
#  'nzpol',
#  'data',
#  'environment',
#  'climatechange',
#  'unfao',
#  'readon',
#  'dsnscience',
#  'environment',
#  'climate',
#  'environment',
#  'maga',
#  'america',
#  'climate',
#  'climate',
#  'politics',
#  'tech',
#  'trump',
#  'climate',
#  'environment',
#  'snowycats',
#  'climate',
#  'gpc',
#  'longisland',
#  'technews',
#  'climate',
#  'norway',
#  'cop',
#  'drainthesw',
#  'newsintweets',
#  'worldwetlandsday',
#  'climatechange',
#  'climate',
#  'egypt',
#  'france',
#  'italy',
#  'climate',
#  'globalwarming',
#  'news',
#  'follow',
#  'retweet',
#  'wine',
#  'climate',
#  'cleantech',
#  'environment',
#  'green',
#  'climatechange',
#  'climate',
#  'indigenous',
#  'climate',
#  'forest',
#  'climate',
#  'env',
#  'cop',
#  'ctl',
#  'indigenous',
#  'rights',
#  'forests',
#  'climate',
#  'environment',
#  'biodiversity',
#  'germany',
#  'california',
#  'climatec',
#  'news',
#  'biotech',
#  'factoftheday',
#  'globalwarming',
#  'russian',
#  'hng',
#  'news',
#  'political',
#  'climate',
#  'environment',
#  'cdnpoli',
#  'cnn',
#  'dailyclimate',
#  'climate',
#  'climatechange',
#  'sab',
#  'worldnews',
#  'climatechange',
#  'globalwarming',
#  'climate',
#  'greatbarrierreef',
#  'climate',
#  'trumppresident',
#  'unsg',
#  'cop',
#  'sapnajha',
#  'climate',
#  'weather',
#  'maga',
#  'america',
#  'cnn',
#  'climate',
#  'climatechange',
#  'climate',
#  'environment',
#  'wsj',
#  'weather',
#  'forecast',
#  'forests',
#  'trump',
#  'climate',
#  'environment',
#  'science',
#  'globalwarming',
#  'climatechange',
#  'cop',
#  'earthday',
#  'chemistrynewslocker',
#  'arnoldschwarzenegger',
#  'arnoldschwarzenegger',
#  'climate',
#  'climate',
#  'ocean',
#  'environment',
#  'worldnews',
#  'news',
#  'science',
#  'climate',
#  'polarvortex',
#  'climate',
#  'parisagreement',
#  'weather',
#  'forecast',
#  'standingrock',
#  'merc',
#  'cnn',
#  'climate',
#  'globalwarming',
#  'beachlife',
#  'climatechange',
#  'pollution',
#  'epa',
#  'uga',
#  'epa',
#  'scottpruitt',
#  'itstimetochange',
#  'cli',
#  'climate',
#  'environment',
#  'breakingnews',
#  'climate',
#  'scitech',
#  'cop',
#  'climatechange',
#  'globalwarming',
#  'education',
#  'climate',
#  'climate',
#  'healthinformation',
#  'gameofthrones',
#  'environment',
#  'climatechange',
#  'climatechange',
#  'security',
#  'drought',
#  'worldnews',
#  'news',
#  'climatechange',
#  'epa',
#  'climate',
#  'pruitt',
#  'arnoldschwarzenegger',
#  'arnoldschwarzenegger',
#  'climatechange',
#  'cnnbrk',
#  'auspol',
#  'climate',
#  'hng',
#  'emory',
#  'climate',
#  'agu',
#  'cnn',
#  'climate',
#  'quirkquestions',
#  'earthchanges',
#  'science',
#  'climate',
#  'environment',
#  'polarbears',
#  'finland',
#  'trump',
#  'mashable',
#  'canberra',
#  'smartnews',
#  'trump',
#  'climate',
#  'environment',
#  'wtf',
#  'spot',
#  'science',
#  'climatech',
#  'chainfeedsdotcom',
#  'climate',
#  'onmedic',
#  'science',
#  'ftcfs',
#  'climatechange',
#  'climate',
#  'climate',
#  'energy',
#  'environment',
#  'water',
#  'ecohotels',
#  'climatechange',
#  'climatechange',
#  'climat',
#  'climate',
#  'biodiversity',
#  'climate',
#  'statesandregions',
#  'epa',
#  'parisagreement',
#  'china',
#  'climate',
#  'environment',
#  'climate',
#  'hydroone',
#  'news',
#  'dachanazoa',
#  'news',
#  'psc',
#  'novanext',
#  'f',
#  'tfb',
#  'climatechange',
#  'concierge',
#  'conciergeservices',
#  'malta',
#  'lifestylemanager',
#  'climate',
#  'adaptation',
#  'climate',
#  'hng',
#  'news',
#  'wsj',
#  'global',
#  'climatechange',
#  'climate',
#  'climate',
#  'cop',
#  'gie',
#  'cdnp',
#  'climatechange',
#  'climate',
#  'ruggerorespigo',
#  'cdnpoli',
#  'cardiffresearch',
#  'climate',
#  'environment',
#  'hastings',
#  'wheat',
#  'news',
#  'tech',
#  'science',
#  'nato',
#  'earthfirst',
#  'parisagreement',
#  'researchhighlight',
#  'newsvideos',
#  'lfc',
#  'efc',
#  'parisagreement',
#  'sopride',
#  'energy',
#  'climate',
#  'climat',
#  'climatefacts',
#  'science',
#  'reuters',
#  'maga',
#  'america',
#  'climate',
#  'trump',
#  'climate',
#  'environment',
#  'sapnajha',
#  'science',
#  'feedly',
#  'veterans',
#  'usn',
#  'climatechange',
#  'maga',
#  'sopride',
#  'energy',
#  'climate',
#  'science',
#  'environment',
#  'smartnews',
#  'tucker',
#  'environment',
#  'climatechange',
#  'climatechange',
#  'cop',
#  'music',
#  'news',
#  'climatechange',
#  'buzz',
#  'globalbuzzlive',
#  'climatechange',
#  'indus',
#  'archaeology',
#  'anthropology',
#  'gots',
#  'climate',
#  'worldnews',
#  'top',
#  'trump',
#  'climate',
#  'harvey',
#  'chemicals',
#  'farmclinic',
#  'environment',
#  'greatbarrierreef',
#  'greatbarrierreef',
#  'harv',
#  'education',
#  'china',
#  'climate',
#  'donaldtrump',
#  'fukushima',
#  'trump',
#  'parisagreement',
#  'news',
#  'almalki',
#  'climatechange',
#  'carbondioxide',
#  'climate',
#  'bcpoli',
#  'greatbarrierreef',
#  'unsg',
#  'cop',
#  'newsintweets',
#  'environment',
#  'climate',
#  'weather',
#  'climate',
#  'beforetheflood',
#  'climatec',
#  'climate',
#  'twosessions',
#  'climate',
#  'worldnews',
#  'news',
#  'trout',
#  'climate',
#  'climate',
#  'climatechange',
#  'carbonbubble',
#  'cop',
#  'climate',
#  'climate',
#  'pakistani',
#  'women',
#  'pakistan',
#  'climatechange',
#  'latest',
#  'rrn',
#  'market',
#  'equity',
#  'climatechange',
#  'smartpipshub',
#  'http',
#  'globalwarning',
#  'greatbarrierreef',
#  'wsj',
#  'sundance',
#  'climatechange',
#  'climate',
#  'climate',
#  'earthday',
#  'gameofthrones',
#  'science',
#  'environment',
#  'politics',
#  'law',
#  'worldnews',
#  'news',
#  'parisagreement',
#  'climate',
#  'karenrebels',
#  'climatechange',
#  'europe',
#  'climate',
#  'tillerson',
#  'climate',
#  'climate',
#  'environment',
#  'clima',
#  'google',
#  'climate',
#  'epa',
#  'climate',
#  'environment',
#  'climatechange',
#  'ece',
#  'scuba',
#  'mostread',
#  'ibgeog',
#  'core',
#  'worldnews',
#  'news',
#  'breakingnews',
#  'auspol',
#  'christian',
#  'news',
#  'science',
#  'climate',
#  'climatemarch',
#  'climatechange',
#  'climate',
#  'fakenewsmedia',
#  'africa',
#  'trump',
#  'climate',
#  'engadget',
#  'business',
#  'zimbabwe',
#  'indianexpress',
#  'time',
#  'climate',
#  'newslytweet',
#  'greatbarrierreef',
#  'climate',
#  'trump',
#  'climatechange',
#  'krtpro',
#  'news',
#  'washingtonpost',
#  'trump',
#  'bottles',
#  'plastic',
#  'yournewstweet',
#  'fragility',
#  'climate',
#  'eaps',
#  'hurricaneharvey',
#  'climatechange',
#  'climatemarch',
#  'greatbarrierreef',
#  'politics',
#  'trump',
#  'usa',
#  'environment',
#  'climatechange',
#  'perufloods',
#  'switch',
#  'mexicogp',
#  'breaking',
#  'parisagreement',
#  'agenda',
#  'animals',
#  'coal',
#  'climate',
#  'environment',
#  'climate',
#  'environment',
#  'unfao',
#  'worldnews',
#  'china',
#  'climatechange',
#  'cheapgames',
#  'climatechange',
#  'cbc',
#  'tech',
#  'ifttt',
#  'followme',
#  'science',
#  'climate',
#  'climate',
#  'globalwarming',
#  'news',
#  'big',
#  'business',
#  'fdlx',
#  'climate',
#  'research',
#  'climate',
#  'chinese',
#  'china',
#  'wiunio',
#  'epa',
#  'pruitt',
#  'china',
#  'trump',
#  'globa',
#  'weather',
#  'forecast',
#  'science',
#  'environment',
#  'cities',
#  'wbef',
#  'climate',
#  'environment',
#  'climate',
#  'sustai',
#  'climate',
#  'trump',
#  'science',
#  'climate',
#  'australia',
#  'news',
#  'turnbull',
#  'auspol',
#  'climatemarch',
#  'cleantech',
#  'energy',
#  'climate',
#  'environ',
#  'climatemarch',
#  'climatechange',
#  'africalive',
#  'pakistan',
#  'business',
#  'environment',
#  'beforetheflood',
#  'trump',
#  'breakingnews',
#  'iceage',
#  'beforetheflood',
#  'sciencedaily',
#  'climatechange',
#  'temperatures',
#  'scientists',
#  'climate',
#  'environment',
#  'climate',
#  'environment',
#  'news',
#  'nicholasstern',
#  'climate',
#  'environment',
#  'cop',
#  'climate',
#  'climate',
#  'environment',
#  'microsoft',
#  'toledo',
#  'ukgov',
#  'fracking',
#  'environment',
#  'conservation',
#  'science',
#  'yearinreview',
#  'climatechange',
#  'earthhour',
#  'realtime',
#  'news',
#  'trump',
#  'greatbarrierreef',
#  'climate',
#  'thisdayinhistory',
#  'record',
#  'climatechange',
#  'ntrs',
#  'sheikhhasina',
#  'world',
#  'cop',
#  'c',
#  'americaninstituteofarchitects',
#  'breaking',
#  'news',
#  'climate',
#  'enviro',
#  'time',
#  'greatbarrierreef',
#  'climate',
#  'climate',
#  'climate',
#  'frenchelection',
#  'melechoninenglish',
#  'science',
#  'greenland',
#  'climate',
#  'climatechange',
#  'dailyclimate',
#  'climate',
#  'pruittresign',
#  'climatemarch',
#  'climatechangeisreal',
#  'googlealerts',
#  'exxon',
#  'waynetracker',
#  'pruitt',
#  'climate',
#  'plastic',
#  'climate',
#  'science',
#  'policy',
#  'cnn',
#  'climate',
#  'environment',
#  'topnews',
#  'topnews',
#  'trump',
#  'climatechange',
#  'donaldtrump',
#  'monaco',
#  'environment',
#  'nature',
#  'exxonmobil',
#  'p',
#  'climate',
#  'png',
#  'local',
#  'news',
#  'update',
#  'worldgovsummit',
#  'climatechange',
#  'greatbarrierreef',
#  't',
#  'harvey',
#  'sabcnews',
#  'irpfellows',
#  'breaking',
#  'cities',
#  'cnnbrk',
#  'susta',
#  'usa',
#  'breaking',
#  'news',
#  'climatemarch',
#  'inspired',
#  'kickass',
#  'trump',
#  'climate',
#  'environm',
#  'greenland',
#  'news',
#  'almalki',
#  'wired',
#  'breakingnews',
#  'geogr',
#  'orleg',
#  'liveonk',
#  'news',
#  'oceansummit',
#  'trump',
#  'cop',
#  'trump',
#  'climatechange',
#  'phenology',
#  'trump',
#  'climate',
#  'climate',
#  'first',
#  'coal',
#  'climate',
#  'climatechange',
#  'pakistan',
#  'climate',
#  'climate',
#  'arctic',
#  'weather',
#  'forecast',
#  'greatbarrierreef',
#  'longisland',
#  'technews',
#  'actonclim',
#  'climate',
#  'asia',
#  'leopards',
#  'climate',
#  'cop',
#  'cop',
#  'unsg',
#  'hr',
#  'climate',
#  'nigeria',
#  'news',
#  'trump',
#  'trump',
#  'climate',
#  'environm',
#  'clim',
#  'climate',
#  'sustainableenergy',
#  'urlweb',
#  'italian',
#  'wines',
#  'climate',
#  'environment',
#  'worldpenguinday',
#  'viceonhbo',
#  'climatechange',
#  'earthday',
#  'markruffalo',
#  'news',
#  'qldpol',
#  'stopadani',
#  'aus',
#  'cnn',
#  'data',
#  'global',
#  'news',
#  'casino',
#  'climate',
#  'accountancy',
#  'worldnews',
#  'news',
#  'breakingnews',
#  'trump',
#  'climate',
#  'environment',
#  'climatemarch',
#  'earthhour',
#  'earthhour',
#  'breaking',
#  'trumptransition',
#  'presidentelecttrump',
#  'maga',
#  'andreachu',
#  'environment',
#  'climatechange',
#  'globalwarming',
#  'science',
#  'healthcare',
#  'comms',
#  'news',
#  'climatechange',
#  'commonwealth',
#  'climate',
#  'environment',
#  'afyahouseprobe',
#  'asia',
#  'climate',
#  'climatechange',
#  'tree',
#  'beforetheflood',
#  'climate',
#  'globalwarning',
#  'climatechange',
#  'hnn',
#  'climate',
#  'environment',
#  'geography',
#  'intelgroup',
#  'hannity',
#  'weather',
#  'forecast',
#  'climate',
#  'climate',
#  'environ',
#  'carbonfootprint',
#  'gapframeweek',
#  'planet',
#  'oceans',
#  'climate',
#  'environment',
#  'trump',
#  'climatechange',
#  'westernsahara',
#  'roguenasa',
#  'climate',
#  'law',
#  'worldturtleday',
#  'climate',
#  'environment',
#  'ireland',
#  'simondonner',
#  'china',
#  'trump',
#  'climat',
#  'iran',
#  'earthday',
#  'cop',
#  'arctic',
#  'tytlive',
#  'breaking',
#  'davos',
#  'wef',
#  'climatechange']

# %% [markdown]
# #### __Create word frequency__

# %%
word_freq_pro_climate = nltk.FreqDist(pro_climate_change_unnest)

word_freq_pro_climate
# Out:
# FreqDist({'climate': 137, 'climatechange': 66, 'environment': 47, 'news': 32, 'trump': 25, 'science': 18, 'cop': 17, 'greatbarrierreef': 14, 'parisagreement': 9, 'worldnews': 9, ...})

# %% [markdown]
# #### __Create dataframe__

# %%
df_pro_climate_change = pd.DataFrame({'Hashtags':list(word_freq_pro_climate.keys()),'Count':list(word_freq_pro_climate.values())})

df_pro_climate_change.head(10)
# Out:
#            Hashtags  Count
# 0  climate           137
# 1  climatechange     66
# 2  skpol             1
# 3  parisagreement    9
# 4  environment       47
# 5  india             1
# 6  greatbarrierreef  14
# 7  exxonmobil        2
# 8  cop               17
# 9  geographyteacher  1

# %% [markdown]
# #### __Plot the data of the most used Hashtags__ `pro climate change`

# %%
df_pro_climate_change_plot = df_pro_climate_change.nlargest(20,columns='Count')

sns.barplot(data=df_pro_climate_change_plot,y='Hashtags',x='Count')
sns.despine()

# %% [markdown]
# #### __Anti climate change__

# %%
anti_climate_change = Hashtags_Extract(df_train['tidy_message'][df_train['sentiment']==-1])
anti_climate_change
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['nomorescams', 'nomoredemocrats', 'draintheswamp'],
#  [],
#  ['fakenews'],
#  ['myth', 'maga', 'stepfo'],
#  [],
#  ['opchemtrails'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['earthday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['miamibeachbowl'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['liberals'],
#  [],
#  ['liberallogic'],
#  [],
#  [],
#  ['trump'],
#  [],
#  [],
#  ['qanda'],
#  [],
#  ['snow', 'egypt'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trump'],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['marchforbabies'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['lies'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['economy', 'national'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['londonattacks'],
#  [],
#  [],
#  ['standupforscience'],
#  ['cashinin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatescam', 'greenscam', 'teaparty', 'tcot', 'pjnet'],
#  [],
#  ['opchemtrails'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['blizzard'],
#  [],
#  ['opchemtrails'],
#  [],
#  ['maga', 'trumptrain', 'dobbs'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['feedly'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sciencecelebs', 'libtards', 'unicornsarereal', 'snowflakes'],
#  [],
#  ['whywemustimpeachtrumpin'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['presidenttrump'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['day', 'obamacare', 'maga'],
#  ['bullshit', 'fakescience'],
#  [],
#  ['eugenics', 'science'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['taxday'],
#  [],
#  ['trump'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sad'],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  ['eco', 'green'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trump'],
#  ['qanda'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['planetx'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trump'],
#  ['parisagreement'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['goreeffect'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['stfu'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['maga'],
#  [],
#  [],
#  ['peoplesclimatemarch'],
#  [],
#  [],
#  [],
#  [],
#  ['unitednations', 'co'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['newvettingquestions'],
#  [],
#  [],
#  ['maga'],
#  ['iamaclim'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['snakeoilsales'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['liars'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fakenews'],
#  [],
#  [],
#  [],
#  ['michaelcreighton', 'environmental', 'climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['arctic'],
#  [],
#  [],
#  [],
#  [],
#  ['billnye', 'cnn'],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trump'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['whatilearnedtoday'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hann'],
#  [],
#  ['ifonlytheearthcouldspeak'],
#  [],
#  ['climatechange', 'ausecon', 'ausbiz', 'auspol'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['obamalega'],
#  [],
#  [],
#  [],
#  [],
#  ['americafirst'],
#  [],
#  [],
#  ['ooc'],
#  [],
#  [],
#  [],
#  [],
#  ['pruitts'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fact', 'marchagainstsharia'],
#  [],
#  [],
#  [],
#  [],
#  ['climatemarch'],
#  [],
#  [],
#  ['climatemarch'],
#  [],
#  [],
#  [],
#  [],
#  ['buffoons'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['benghazi'],
#  [],
#  [],
#  [],
#  ['qanda'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cnn', 'cnnisisis', 'trump', 'draintheswamp'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['trumpriot'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['maga'],
#  [],
#  [],
#  [],
#  ['liberalhysteria'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['tcot', 'p'],
#  [],
#  ['leowatch'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  ['climatescam', 'pjnet'],
#  ['hypocrite', 'mag'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['corr'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['toronto', 'chemtrails', 'geoengineering', 'srm'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['stepstoreverseclimatechange'],
#  [],
#  [],
#  [],
#  [],
#  ['maga'],
#  [],
#  ['ma'],
#  [],
#  [],
#  ['climatechange'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['blamerussia', 'russiagate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pussygeneration'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climategate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['solar'],
#  [],
#  ['algore', 'climatechange', 'snowstorm'],
#  ['fakenews'],
#  [],
#  [],
#  [],
#  ['globalwarming', 'epa'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['londonattacks'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['obamalegacy'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['parisagreement'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['globalwarming', 'climatechange', 'hoax', 'fraud', 'fail', 'lie'],
#  ['wakeupamerica'],
#  [],
#  [],
#  ['glaciation'],
#  [],
#  ['usfa'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['tcot', 'ccot', 'gop', 'maga'],
#  [],
#  [],
#  ['maga'],
#  [],
#  [],
#  [],
#  ['nad'],
#  [],
#  [],
#  ['londonbridge'],
#  [],
#  [],
#  ['cnn'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['carbontax', 'rockymountains', 'opchemtr'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fakeglobal'],
#  ['globalwarming', 'electriccars'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ableg'],
#  ['ipcc'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['covfefe'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['opchemtrails', 'srm'],
#  [],
#  [],
#  [],
#  [],
#  ['climatechange', 'environment'],
#  [],
#  [],
#  ['parisagr'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['marchforscience'],
#  ['fakenews'],
#  [],
#  ['feedly'],
#  [],
#  ['dailycrowder'],
#  [],
#  [],
#  [],
#  ['trudeau'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['senatehearing', 'tillerson'],
#  ['endclimatehysteria'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['listen'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['opchempba', 'sai'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climatescam'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['climate'],
#  [],
#  [],
#  [],
#  [],
#  ['tcot', 'p'],
#  [],
#  ['climatechangehoax', 'maga'],
#  [],
#  ...]

# %%
anti_climate_change_unnest = sum(anti_climate_change,[])

# %%
anti_climate_change_unnest
# Out:
# ['nomorescams',
#  'nomoredemocrats',
#  'draintheswamp',
#  'fakenews',
#  'myth',
#  'maga',
#  'stepfo',
#  'opchemtrails',
#  'earthday',
#  'miamibeachbowl',
#  'liberals',
#  'liberallogic',
#  'trump',
#  'qanda',
#  'snow',
#  'egypt',
#  'trump',
#  'climatechange',
#  'marchforbabies',
#  'lies',
#  'economy',
#  'national',
#  'londonattacks',
#  'standupforscience',
#  'cashinin',
#  'climatescam',
#  'greenscam',
#  'teaparty',
#  'tcot',
#  'pjnet',
#  'opchemtrails',
#  'blizzard',
#  'opchemtrails',
#  'maga',
#  'trumptrain',
#  'dobbs',
#  'feedly',
#  'sciencecelebs',
#  'libtards',
#  'unicornsarereal',
#  'snowflakes',
#  'whywemustimpeachtrumpin',
#  'presidenttrump',
#  'day',
#  'obamacare',
#  'maga',
#  'bullshit',
#  'fakescience',
#  'eugenics',
#  'science',
#  'taxday',
#  'trump',
#  'sad',
#  'climate',
#  'eco',
#  'green',
#  'trump',
#  'qanda',
#  'planetx',
#  'trump',
#  'parisagreement',
#  'goreeffect',
#  'stfu',
#  'maga',
#  'peoplesclimatemarch',
#  'unitednations',
#  'co',
#  'newvettingquestions',
#  'maga',
#  'iamaclim',
#  'snakeoilsales',
#  'liars',
#  'fakenews',
#  'michaelcreighton',
#  'environmental',
#  'climate',
#  'arctic',
#  'billnye',
#  'cnn',
#  'climate',
#  'trump',
#  'whatilearnedtoday',
#  'hann',
#  'ifonlytheearthcouldspeak',
#  'climatechange',
#  'ausecon',
#  'ausbiz',
#  'auspol',
#  'climate',
#  'obamalega',
#  'americafirst',
#  'ooc',
#  'pruitts',
#  'fact',
#  'marchagainstsharia',
#  'climatemarch',
#  'climatemarch',
#  'buffoons',
#  'benghazi',
#  'qanda',
#  'cnn',
#  'cnnisisis',
#  'trump',
#  'draintheswamp',
#  'trumpriot',
#  'maga',
#  'liberalhysteria',
#  'tcot',
#  'p',
#  'leowatch',
#  'climate',
#  'climate',
#  'climatescam',
#  'pjnet',
#  'hypocrite',
#  'mag',
#  'corr',
#  'toronto',
#  'chemtrails',
#  'geoengineering',
#  'srm',
#  'stepstoreverseclimatechange',
#  'maga',
#  'ma',
#  'climatechange',
#  'blamerussia',
#  'russiagate',
#  'climate',
#  'pussygeneration',
#  'climategate',
#  'solar',
#  'algore',
#  'climatechange',
#  'snowstorm',
#  'fakenews',
#  'globalwarming',
#  'epa',
#  'londonattacks',
#  'obamalegacy',
#  'parisagreement',
#  'globalwarming',
#  'climatechange',
#  'hoax',
#  'fraud',
#  'fail',
#  'lie',
#  'wakeupamerica',
#  'glaciation',
#  'usfa',
#  'tcot',
#  'ccot',
#  'gop',
#  'maga',
#  'maga',
#  'nad',
#  'londonbridge',
#  'cnn',
#  'carbontax',
#  'rockymountains',
#  'opchemtr',
#  'fakeglobal',
#  'globalwarming',
#  'electriccars',
#  'ableg',
#  'ipcc',
#  'covfefe',
#  'climate',
#  'opchemtrails',
#  'srm',
#  'climatechange',
#  'environment',
#  'parisagr',
#  'marchforscience',
#  'fakenews',
#  'feedly',
#  'dailycrowder',
#  'trudeau',
#  'senatehearing',
#  'tillerson',
#  'endclimatehysteria',
#  'listen',
#  'opchempba',
#  'sai',
#  'climatescam',
#  'climate',
#  'tcot',
#  'p',
#  'climatechangehoax',
#  'maga',
#  'election',
#  'climatechange',
#  'junkscience',
#  'rednationrising',
#  'greatamerica',
#  'maga',
#  'period',
#  'parisagreement',
#  'climatechangein',
#  'iamright',
#  'presidenttrump',
#  'chemtrails',
#  'antisemitic',
#  'maga',
#  'potus',
#  'truepundit',
#  'epa',
#  'globalwarming',
#  'tucker',
#  'parisagreement',
#  'climate',
#  'trumpriot',
#  't',
#  'islamicstate',
#  'tco',
#  'jan',
#  'justasking',
#  'science',
#  'maga',
#  'trump',
#  'g',
#  'confessyourunpopularopinion',
#  'science',
#  'londonbridge',
#  'maga',
#  'climatechange',
#  'globalwarming',
#  'hoax',
#  'peoplesclimatemarch',
#  'thingstrumpthinksareoverrated',
#  'climatemarch',
#  'nosurprisehere',
#  'globalcooling',
#  'climate',
#  'politicallyreactive',
#  'cdnpoli',
#  'media',
#  'brrrr',
#  'hypocrisy',
#  'agenda']

# %% [markdown]
# #### __Create word frequency__

# %%
word_freq_anti_climate = nltk.FreqDist(anti_climate_change_unnest)

word_freq_anti_climate
# Out:
# FreqDist({'maga': 14, 'climate': 11, 'trump': 8, 'climatechange': 8, 'globalwarming': 5, 'fakenews': 4, 'opchemtrails': 4, 'tcot': 4, 'parisagreement': 4, 'qanda': 3, ...})

# %% [markdown]
# #### __Create dataframe__

# %%
df_anti_climate_change = pd.DataFrame({'Hashtags':list(word_freq_anti_climate.keys()),'Count':list(word_freq_anti_climate.values())})

df_anti_climate_change.head(10)
# Out:
#           Hashtags  Count
# 0  nomorescams      1
# 1  nomoredemocrats  1
# 2  draintheswamp    2
# 3  fakenews         4
# 4  myth             1
# 5  maga             14
# 6  stepfo           1
# 7  opchemtrails     4
# 8  earthday         1
# 9  miamibeachbowl   1

# %% [markdown]
# #### __Plot the data of the most used Hashtags__ `anti climate change`

# %%
df_anti_climate_change_plot = df_anti_climate_change.nlargest(20,columns='Count') 

sns.barplot(data=df_anti_climate_change_plot,y='Hashtags',x='Count')
sns.despine()

# %% [markdown]
# # 10.__Model building__

# %%
X = df_lemma
y = df_train['sentiment']

# %% [markdown]
# ### 10.1 __Split  data__

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
#  ### 10.2 __Vectorize  data__

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def clean_title(text):
   text = " ".join([word.lower() for word in text if word not in string.punctuation])
   title = re.split('\W+', text)
   text = [ps.stem(word) for word in title if word not in nltk.corpus.stopwords.words('english')]
   return text

# %%
#create vector object
cv = CountVectorizer(analyzer=clean_title) 

# transfrom the values based on X_train
X_train_vect = cv.fit_transform(X_train).toarray()

# %%
#transform the values X_test
X_test_vect = cv.transform(X_test).toarray()

# %%
#convert y_train to array
y_train_vect = np.array(y_train)

# %% [markdown]
# ### 10.3 __Multinomial naive bayes__

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mn = MultinomialNB()

# %%
mn.fit(X_train_vect, y_train_vect)
# Out:
# MultinomialNB()

# %%
y_pred = mn.predict(X_test_vect)

# %%
print("The accuracy score of the multinomial Naive Bayes is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n", classification_report(y_test, y_pred))
# Out:
# The accuracy score of the multinomial Naive Bayes is: 0.7054361567635904
#
#
# Classification Report:
#
#                precision    recall  f1-score   support
#
#           -1       0.68      0.28      0.40       278
#            0       0.58      0.32      0.41       425
#            1       0.72      0.86      0.78      1755
#            2       0.70      0.73      0.72       706
#
#     accuracy                           0.71      3164
#    macro avg       0.67      0.55      0.58      3164
# weighted avg       0.69      0.71      0.68      3164

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, y_pred,average='micro')
precision = precision_score(y_test, y_pred,average='micro')
recall = recall_score(y_test, y_pred,average='micro')

# %%
# Create dictionaries for the data we want to log
params = {
          "model_type": "Multinomial naive bayes",
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
#experiment.log_parameters(params)
#experiment.log_metrics(metrics)

# %% [markdown]
# ### 10.4 __Decision Trees__

# %%
tree = DecisionTreeClassifier(random_state=42)

# %%
tree.fit(X_train_vect,y_train_vect)

# %%
y_pred = tree.predict(X_test_vect)

# %% [markdown]
# #### __Model tuning__

# %%
#Assesing model
print("The accuracy score of the decision tree is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n", classification_report(y_test, y_pred))

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, y_pred,average='micro')
precision = precision_score(y_test, y_pred,average='micro')
recall = recall_score(y_test, y_pred,average='micro')

# %%
# Create dictionaries for the data we want to log
params = {
          "model_type": "Decision Trees",
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
experiment.display()

# %% [markdown]
# ### 10.5 __Random Trees__

# %%
#Tuning the model with n_estimators
forest = RandomForestClassifier(n_estimators=100, random_state=10)

# %%
forest.fit(X_train_vect,y_train_vect)

# %%
y_pred = forest.predict(X_test_vect)

# %%
#Assesing model
print("The accuracy score of the random forest is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n", classification_report(y_test, y_pred))

# %%
experiment.end()

# %% [markdown]
# ### 10.6 __Support Vector Machine__

# %%
from sklearn import svm

# %%
clf = svm.SVC()
clf.fit(X_train_vect, y_train_vect)

# %%
y_pred = clf.predict(X_test_vect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-48d7002375f2> in <module>
# ----> 1 y_pred = forest.predict(X_test_vect)
#
# NameError: name 'forest' is not defined

# %%
nfolds = 2

Cs = [0.001, 0.01, 0.1, 1, 10]
gammas = [0.001, 0.01, 0.1, 1]

param_grid = {
    'C'     : Cs, 
    'gamma' : gammas
    }

grid_SVM = GridSearchCV(SVC(), param_grid, scoring='f1', cv=nfolds)
grid_SVM.fit(X_train_vect, y_train_vect)

# %%
#Assesing model
print("The accuracy score of the random forest is:", accuracy_score(y_test, y_pred))
print("\n\nClassification Report:\n\n", classification_report(y_test, y_pred))

# %%
#need to take few values
